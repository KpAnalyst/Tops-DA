# %% [markdown]
# # Assessment 1:

# %%
import pandas as pd

# %%
""" 1) Import pandas and read in the banklist.csv file into a dataframe called Banks."""
banks=pd.read_csv(r"C:\Users\KEYUR\Desktop\Keyur Tops\assessment\numpy\banklist.csv")
banks
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 548                                 Superior Bank, FSB            Hinsdale
# 549                                Malta National Bank               Malta
# 550                    First Alliance Bank & Trust Co.          Manchester
# 551                  National State Bank of Metropolis          Metropolis
# 552                                   Bank of Honolulu            Honolulu
#
# ...

# %%
""" 2) Show the head of the dataframe."""
banks.head(10)
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
# 5                             Harvest Community Bank          Pennsville  NJ
# 6                                        Allied Bank            Mulberry  AR
# 7                       The Woodbury Banking Company            Woodbury  GA
# 8                             First CornerStone Bank     King of Prussia  PA
# 9                                 Trust Company Bank             Memphis  TN
#
#     CERT                Acquiring Institution Closing Date Updated Date
# ...

# %%
""" 3) What are the column names? """
print(banks.columns)
# Out:
# Index(['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution',
#        'Closing Date', 'Updated Date'],
#       dtype='object')

# %%
""" 4) How many States (ST) are represented in this data set?"""
s1 = len(banks["ST"].unique())
print("Number of unique states:", s1)
# Out:
# Number of unique states: 44

# %%
""" 5) Get a list or array of all the states in the data set."""
s2 = list(set(banks["ST"]))
print(s2)
# Out:
# ['MS', 'ID', 'NY', 'NH', 'OR', 'NM', 'UT', 'TX', 'OK', 'SC', 'CA', 'KS', 'OH', 'PR', 'NV', 'CT', 'IA', 'WA', 'AL', 'IN', 'PA', 'MO', 'MI', 'HI', 'NE', 'FL', 'CO', 'GA', 'WY', 'LA', 'AR', 'AZ', 'NJ', 'MD', 'MA', 'WV', 'SD', 'TN', 'KY', 'NC', 'MN', 'WI', 'VA', 'IL']

# %%
"""6) What are the top 5 states with the most failed banks? """
s3 = banks["ST"].value_counts().nlargest(5)
print("The top 5 States with most failed banks is:",s3)
# Out:
# The top 5 States with most failed banks is: ST
# GA    93
# FL    75
# IL    68
# CA    41
# MN    23
# Name: count, dtype: int64

# %%
""" 7) What are the top 5 acquiring institutions? """
s4 = banks["Acquiring Institution"].value_counts().nlargest(5)
print(s4)
# Out:
# Acquiring Institution
# No Acquirer                            31
# State Bank and Trust Company           12
# First-Citizens Bank & Trust Company    11
# Ameris Bank                            10
# U.S. Bank N.A.                          9
# Name: count, dtype: int64

# %%
""" 8) How many banks has the State Bank of Texas acquired? How many of them were actually in Texas?"""
s5 = banks[banks["Acquiring Institution"] == "State Bank of Texas"].shape[0]
s6 = banks[(banks["Acquiring Institution"] == "State Bank of Texas") & (banks["ST"] == "TX")].shape[0]
print("State Bank of Texas acquired ",s5," banks, out of which", s6," were in Texas.")
# Out:
# State Bank of Texas acquired  3  banks, out of which 1  were in Texas.

# %%
""" #9) What is the most common city in California for a bank to fail in? """
s7 = banks.loc[banks["ST"] == "CA", "City"].value_counts().idxmax()
print(s7)
# Out:
# Los Angeles

# %% [markdown]
# # Assessment 2:

# %%
import pandas as pd
import matplotlib.pyplot as plt
f = pd.read_csv(r"C:\Users\KEYUR\Desktop\Keyur Tops\assessment\numpy\historical_automobile_sales.csv")  
f
# Out:
#            Date  Year Month  Recession  Consumer_Confidence  \
# 0     1/31/1980  1980   Jan          1               108.24
# 1     2/29/1980  1980   Feb          1                98.75
# 2     3/31/1980  1980   Mar          1               107.48
# 3     4/30/1980  1980   Apr          1               115.01
# 4     5/31/1980  1980   May          1                98.72
# ..          ...   ...   ...        ...                  ...
# 523   8/31/2023  2023   Aug          0               103.36
# 524   9/30/2023  2023   Sep          0               101.55
# 525  10/31/2023  2023   Oct          0               124.66
# 526  11/30/2023  2023   Nov          0                97.09
# 527  12/31/2023  2023   Dec          0                95.92
#
#      Seasonality_Weight      Price  Advertising_Expenditure  Competition  \
# 0                  0.50  27483.571                     1558            7
# 1                  0.75  24308.678                     3048            4
# ...

# %%
"""Q 1: Develop a Line chart using the functionality of pandas to show how automobile sales fluctuate from year to year. """
p1 = f.groupby("Year")["Automobile_Sales"].sum()

p1.plot(kind="line",color="r", marker="*", figsize=(10, 5), title="Automobile Sales Trends Over the Years")
plt.xlabel("Year")
plt.ylabel("Total Sales")
plt.grid()
plt.show()

# %%
"""Q 2: Plot different lines for categories of vehicle type and analyze the trend to answer the question Is there a noticeable difference in 
sales trends between different vehicle types during recession periods?"""
p2= f.groupby(["Year", "Vehicle_Type"])["Automobile_Sales"].sum().unstack()
plt.figure(figsize=(12, 6))
for i in p2:
    plt.plot(p2.index, p2[i], marker="^", label=i)
plt.xlabel("Year")
plt.ylabel("Total Sales")
plt.title("Automobile Sales by Vehicle Type")
plt.legend(title="Vehicle Type")
plt.grid()
plt.show()

# %%
pip install --upgrade seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
"""Q 3: Use the functionality of Seaborn Library to create a visualization to compare the sales trend per vehicle type for
a recession period with a non- recession period."""
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.lineplot(data=f, x="Year", y="Automobile_Sales", hue="Vehicle_Type", style="Recession", markers=["^","o"], dashes=False)
plt.xlabel("Year")
plt.ylabel("Sales")
plt.title("Sales Trend per Vehicle Type: Recession vs. Non-Recession")
plt.legend(title="Vehicle Type & Recession Status")
plt.grid()
plt.show()

# %%
g = sns.FacetGrid(f, col="Recession", height=5, aspect=1.5)
g.map_dataframe(sns.lineplot, x="Year", y="Automobile_Sales", hue="Vehicle_Type", palette="plasma", marker="o")

g.set_axis_labels("Year", "Total Sales")
g.set_titles("Recession: {col_name}")
g.add_legend()
plt.show()

# %%
"""Q 4: Now you want to compare the sales of different vehicle types during a recession and a non-recession period"""
plt.figure(figsize=(10, 6))
sns.barplot(data=f, x="Vehicle_Type", y="Automobile_Sales", hue="Recession", palette="PiYG")
plt.xlabel("Vehicle Type")
plt.ylabel("Total Sales")
plt.title("Sales Comparison of Vehicle Types (Recession vs Non-Recession)")
plt.legend(title="Recession (0 = No, 1 = Yes)")
plt.xticks(rotation=45)
plt.grid()
plt.show()
